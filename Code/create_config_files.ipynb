# %% [markdown]
# This Jupyter notebook contains code to generate GCAM configuration files, varying future water supply (runoff)

# %% [markdown]
# # Ensemble Description: Hydrologic Uncertainty
# # Date: 02/07/2024

# %% [markdown]
# ### Factors to Vary in this Ensemble:
#
# future runoff (water supply)

# %%
#Import Statements
import xml.etree.ElementTree as ET # documentation: https://docs.python.org/3/library/xml.etree.elementtree.html
import numpy as np
import glob
import os

# %% [markdown]
# ### Base Config File

# %%
# using xml.etree.ElementTree, read in base configuration file, parse, and find ScenarioComponents child
#location of reference configuration file (comes with GCAM distribution)
tree=ET.parse('C:/Users/birnb/Documents/Tufts Research/GCIMS/birnbaum-etal_2024_HydroVariability/Data/config_files/configuration_ref.xml')
root=tree.getroot() # root can be indexed normally, for example try root[0][11].text
scenComp=root.find('ScenarioComponents')

# %%
# print out xml contents for quick viewing
for child in root:
    for i in range(len(child)):
        print(child.tag, child[i].attrib, child[i].text)
    print('')
# Out:
# Files {'name': 'xmlInputFileName'} ../input/gcamdata/xml/modeltime.xml
# Files {'name': 'BatchFileName'} batch_ag.xml
# Files {'name': 'policy-target-file'} ../input/policy/forcing_target_4p5.xml
# Files {'name': 'GHGInputFileName'} ../input/magicc/inputs/input_gases.emk
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'xmldb-location'} ../output/database_basexdb
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'restart'} ./restart/restart
# Files {'write-output': '1', 'append-scenario-name': '1', 'name': 'xmlDebugFileName'} debug.xml
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'climatFileName'} gas.emk
# Files {'write-output': '1', 'append-scenario-name': '1', 'name': 'costCurvesOutputFileName'} cost_curves.xml
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'batchCSVOutputFile'} batch-csv-out.csv
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'supplyDemandOutputFileName'} SDCurves.csv
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'flow-graph'} gcam-flow-graph.dot
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'dependencyGraphName'} DependencyGraph.dot
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'landAllocatorGraphName'} LandAllocatorGraph.dot
#
# ScenarioComponents {'name': 'climate'} ../input/gcamdata/xml/hector.xml
# ScenarioComponents {'name': 'socioeconomics'} ../input/gcamdata/xml/socioeconomics_gSSP2.xml
# ScenarioComponents {'name': 'resources'} ../input/gcamdata/xml/resources.xml
# ScenarioComponents {'name': 'energy_supply'} ../input/gcamdata/xml/en_supply.xml
# ScenarioComponents {'name': 'energy_transformation'} ../input/gcamdata/xml/en_transformation.xml
# ScenarioComponents {'name': 'elec_water_base'} ../input/gcamdata/xml/electricity_water.xml
# ScenarioComponents {'name': 'heat'} ../input/gcamdata/xml/heat.xml
# ScenarioComponents {'name': 'hydrogen'} ../input/gcamdata/xml/hydrogen.xml
# ScenarioComponents {'name': 'energy_distribution'} ../input/gcamdata/xml/en_distribution.xml
# ScenarioComponents {'name': 'other_industry'} ../input/gcamdata/xml/other_industry.xml
# ScenarioComponents {'name': 'industry_income_elas'} ../input/gcamdata/xml/other_industry_incelas_gssp2.xml
# ScenarioComponents {'name': 'iron_steel'} ../input/gcamdata/xml/iron_steel.xml
# ScenarioComponents {'name': 'iron_steel_income_elas'} ../input/gcamdata/xml/iron_steel_incelas_gssp2.xml
# ScenarioComponents {'name': 'Off_road'} ../input/gcamdata/xml/Off_road.xml
# ScenarioComponents {'name': 'Off_road_income_elas'} ../input/gcamdata/xml/Off_road_incelas_gssp2.xml
# ScenarioComponents {'name': 'chemical'} ../input/gcamdata/xml/chemical.xml
# ScenarioComponents {'name': 'chemical_income_elas'} ../input/gcamdata/xml/chemical_incelas_gssp2.xml
# ScenarioComponents {'name': 'aluminum'} ../input/gcamdata/xml/aluminum.xml
# ScenarioComponents {'name': 'aluminum_income_elas'} ../input/gcamdata/xml/aluminum_incelas_gssp2.xml
# ScenarioComponents {'name': 'cement'} ../input/gcamdata/xml/cement.xml
# ScenarioComponents {'name': 'cement_income_elas'} ../input/gcamdata/xml/cement_incelas_gssp2.xml
# ScenarioComponents {'name': 'fertilizer_energy'} ../input/gcamdata/xml/en_Fert.xml
# ScenarioComponents {'name': 'hddcdd'} ../input/gcamdata/xml/HDDCDD_constdd_no_GCM.xml
# ScenarioComponents {'name': 'building'} ../input/gcamdata/xml/building_det.xml
# ScenarioComponents {'name': 'transportation'} ../input/gcamdata/xml/transportation_UCD_CORE.xml
# ScenarioComponents {'name': 'carbon_content'} ../input/gcamdata/xml/Ccoef.xml
# ScenarioComponents {'name': 'carbon_storage'} ../input/gcamdata/xml/Cstorage.xml
# ScenarioComponents {'name': 'ag_base'} ../input/gcamdata/xml/ag_For_Past_bio_base_IRR_MGMT.xml
# ScenarioComponents {'name': 'ag_cost'} ../input/gcamdata/xml/ag_cost_IRR_MGMT.xml
# ScenarioComponents {'name': 'ag_prodchange'} ../input/gcamdata/xml/ag_prodchange_ref_IRR_MGMT.xml
# ScenarioComponents {'name': 'residue_bio'} ../input/gcamdata/xml/resbio_input_IRR_MGMT.xml
# ScenarioComponents {'name': 'animal'} ../input/gcamdata/xml/an_input.xml
# ScenarioComponents {'name': 'fertilizer'} ../input/gcamdata/xml/ag_Fert_IRR_MGMT.xml
# ScenarioComponents {'name': 'land1'} ../input/gcamdata/xml/land_input_1.xml
# ScenarioComponents {'name': 'land2'} ../input/gcamdata/xml/land_input_2.xml
# ScenarioComponents {'name': 'land3'} ../input/gcamdata/xml/land_input_3_IRR.xml
# ScenarioComponents {'name': 'land4'} ../input/gcamdata/xml/land_input_4_IRR_MGMT.xml
# ScenarioComponents {'name': 'land5'} ../input/gcamdata/xml/land_input_5_IRR_MGMT.xml
# ScenarioComponents {'name': 'protected_land2'} ../input/gcamdata/xml/protected_land_input_2.xml
# ScenarioComponents {'name': 'protected_land3'} ../input/gcamdata/xml/protected_land_input_3.xml
# ScenarioComponents {'name': 'demand'} ../input/gcamdata/xml/ag_an_demand_input.xml
# ScenarioComponents {'name': 'bio_trade'} ../input/gcamdata/xml/bio_trade.xml
# ScenarioComponents {'name': 'ag_trade'} ../input/gcamdata/xml/ag_trade.xml
# ScenarioComponents {'name': 'unlim_supply_water'} ../input/gcamdata/xml/unlimited_water_supply.xml
# ScenarioComponents {'name': 'water_supply'} ../input/gcamdata/xml/water_supply_constrained.xml
# ScenarioComponents {'name': 'water_desal'} ../input/gcamdata/xml/desalination.xml
# ScenarioComponents {'name': 'water_td'} ../input/gcamdata/xml/water_td.xml
# ScenarioComponents {'name': 'efw_coefs'} ../input/gcamdata/xml/EFW_input_coefs.xml
# ScenarioComponents {'name': 'efw_irr'} ../input/gcamdata/xml/EFW_irrigation.xml
# ScenarioComponents {'name': 'efw_mfg'} ../input/gcamdata/xml/EFW_manufacturing.xml
# ScenarioComponents {'name': 'efw_muni'} ../input/gcamdata/xml/EFW_municipal.xml
# ScenarioComponents {'name': 'ag_water'} ../input/gcamdata/xml/ag_water_input_IRR_MGMT.xml
# ScenarioComponents {'name': 'elec_water_coef'} ../input/gcamdata/xml/electricity_water_coefs.xml
# ScenarioComponents {'name': 'ind_water'} ../input/gcamdata/xml/water_demand_industry.xml
# ScenarioComponents {'name': 'an_water'} ../input/gcamdata/xml/water_demand_livestock.xml
# ScenarioComponents {'name': 'municipal_water'} ../input/gcamdata/xml/water_demand_municipal.xml
# ScenarioComponents {'name': 'primary_ene_water'} ../input/gcamdata/xml/water_demand_primary.xml
# ScenarioComponents {'name': 'ind_urb_proc'} ../input/gcamdata/xml/ind_urb_processing_sectors.xml
# ScenarioComponents {'name': 'nonco2_energy'} ../input/gcamdata/xml/all_energy_emissions.xml
# ScenarioComponents {'name': 'nonco2_fgas'} ../input/gcamdata/xml/all_fgas_emissions.xml
# ScenarioComponents {'name': 'nonco2_unmgd'} ../input/gcamdata/xml/all_unmgd_emissions.xml
# ScenarioComponents {'name': 'nonco2_aglu'} ../input/gcamdata/xml/all_aglu_emissions_IRR_MGMT.xml
# ScenarioComponents {'name': 'nonco2_aglu_prot'} ../input/gcamdata/xml/all_protected_unmgd_emissions.xml
# ScenarioComponents {'name': 'nonco2_em_controls'} ../input/gcamdata/xml/emission_factor_controls.xml
# ScenarioComponents {'name': 'nonco2_energy'} ../input/gcamdata/xml/all_energy_emissions_MAC.xml
# ScenarioComponents {'name': 'nonco2_fgas'} ../input/gcamdata/xml/all_fgas_emissions_MAC.xml
# ScenarioComponents {'name': 'nonco2_aglu'} ../input/gcamdata/xml/all_aglu_emissions_IRR_MGMT_MAC.xml
# ScenarioComponents {'name': 'nonco2_proc'} ../input/gcamdata/xml/ind_urb_processing_sectors_MAC.xml
# ScenarioComponents {'name': 'bio_feedstock_limit'} ../input/gcamdata/xml/liquids_limits.xml
# ScenarioComponents {'name': 'bio_elec_w_feed_limit'} ../input/gcamdata/xml/water_elec_liquids_limits.xml
# ScenarioComponents {'name': 'bio_neg_emiss_budget'} ../input/gcamdata/xml/negative_emissions_budget_gSSP2.xml
# ScenarioComponents {'name': 'bio_externality'} ../input/gcamdata/xml/bio_externality.xml
# ScenarioComponents {'name': 'wind_update'} ../input/gcamdata/xml/onshore_wind.xml
# ScenarioComponents {'name': 'solver'} ../input/solution/cal_broyden_config.xml
#
# Strings {'name': 'scenarioName'} Reference
# Strings {'name': 'debug-region'} USA
# Strings {'name': 'MAGICC-input-dir'} ../input/magicc/inputs
# Strings {'name': 'MAGICC-output-dir'} ../output
# Strings {'name': 'AbatedGasForCostCurves'} CO2
#
# Bools {'name': 'CalibrationActive'} 1
# Bools {'name': 'BatchMode'} 0
# Bools {'name': 'find-path'} 0
# Bools {'name': 'createCostCurve'} 0
# Bools {'name': 'debugChecking'} 0
# Bools {'name': 'simulActive'} 1
# Bools {'name': 'PrintValuesOnGraphs'} 1
# Bools {'name': 'ShowNullPaths'} 0
# Bools {'name': 'PrintPrices'} 1
# Bools {'name': 'QuitFirstFailure'} 0
#
# Ints {'name': 'numMarketsToFindSD'} 10
# Ints {'name': 'numPointsForSD'} 21
# Ints {'name': 'numPointsForCO2CostCurve'} 5
# Ints {'name': 'carbon-output-start-year'} 1705
# Ints {'name': 'climateOutputInterval'} 5
# Ints {'name': 'parallel-grain-size'} 50
# Ints {'name': 'stop-period'} -1
# Ints {'name': 'stop-year'} -1
# Ints {'name': 'restart-period'} -1
# Ints {'name': 'restart-year'} -1
# Ints {'name': 'max-parallelism'} -1

# %% [markdown]
# ### Main For Loop to Edit / Write XML

# %%
# To loop through factors and edit the xml, use this syntax:
# for element in range(len(factor_array)):
#    variable_name = ET.SubElement(scenComp,tag='Value')
#    variable_name.attrib={'name':'name in xml (arbitrary)'}
#    variable_name.text=factor_array[element]

# %%
stoch_list = np.linspace(1,100,100).astype(int)

path = 'C:/Users/birnb/Documents/Tufts Research/GCIMS/birnbaum-etal_2024_HydroVariability/Data/SWM_xml/'
# define path variables to use for factor arrays and output paths
write_path = 'C:/Users/birnb/Documents/Tufts Research/GCIMS/birnbaum-etal_2024_HydroVariability/Data/config_files'

for i in stoch_list:
    # Update Scenario Name
    scen='stochastic_runoff_'+str(i)
    # scenarioName within the Strings element
    root[2][0].text=scen
    # xmldb-location within Files element
    root[0][4].text='/cluster/tufts/lamontagnelab/abirnb01/GCIMS/Abby_paper/GCAM_output/{}'.format(scen) #location on Tufts cluster to store GCAM databases
    root[0][6].attrib={'write-output': '0', 'append-scenario-name': '0', 'name': 'xmlDebugFileName'}

    water_supply = ET.SubElement(scenComp,'Value')
    water_supply.text=path+'stochastic_runoff_'+str(i)+'.xml'
    water_supply.attrib = {'name':'water_supply'}

    tree.write(write_path+scen+'.xml')
    
    scenComp.remove(water_supply)

# %% [markdown]
# # Read the last newly created config file to check formatting:

# %%
# using xml.etree.ElementTree, read in base configuration file, parse, and find ScenarioComponents child
tree=ET.parse(write_path+scen+'.xml')
root=tree.getroot() # root can be indexed normally, for example try root[0][11].text
scenComp=root.find('ScenarioComponents')
# print out xml contents for quick viewing
for child in root:
    for i in range(len(child)):
        print(child.tag, child[i].attrib, child[i].text)
    print('')
# Out:
# Files {'name': 'xmlInputFileName'} ../input/gcamdata/xml/modeltime.xml
# Files {'name': 'BatchFileName'} batch_ag.xml
# Files {'name': 'policy-target-file'} ../input/policy/forcing_target_4p5.xml
# Files {'name': 'GHGInputFileName'} ../input/magicc/inputs/input_gases.emk
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'xmldb-location'} /cluster/tufts/lamontagnelab/abirnb01/GCIMS/Abby_paper/GCAM_output/stochastic_runoff_random_100
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'restart'} ./restart/restart
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'xmlDebugFileName'} debug.xml
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'climatFileName'} gas.emk
# Files {'write-output': '1', 'append-scenario-name': '1', 'name': 'costCurvesOutputFileName'} cost_curves.xml
# Files {'write-output': '1', 'append-scenario-name': '0', 'name': 'batchCSVOutputFile'} batch-csv-out.csv
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'supplyDemandOutputFileName'} SDCurves.csv
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'flow-graph'} gcam-flow-graph.dot
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'dependencyGraphName'} DependencyGraph.dot
# Files {'write-output': '0', 'append-scenario-name': '0', 'name': 'landAllocatorGraphName'} LandAllocatorGraph.dot
#
# ScenarioComponents {'name': 'climate'} ../input/gcamdata/xml/hector.xml
# ScenarioComponents {'name': 'socioeconomics'} ../input/gcamdata/xml/socioeconomics_gSSP2.xml
# ScenarioComponents {'name': 'resources'} ../input/gcamdata/xml/resources.xml
# ScenarioComponents {'name': 'energy_supply'} ../input/gcamdata/xml/en_supply.xml
# ScenarioComponents {'name': 'energy_transformation'} ../input/gcamdata/xml/en_transformation.xml
# ScenarioComponents {'name': 'elec_water_base'} ../input/gcamdata/xml/electricity_water.xml
# ScenarioComponents {'name': 'heat'} ../input/gcamdata/xml/heat.xml
# ScenarioComponents {'name': 'hydrogen'} ../input/gcamdata/xml/hydrogen.xml
# ScenarioComponents {'name': 'energy_distribution'} ../input/gcamdata/xml/en_distribution.xml
# ScenarioComponents {'name': 'other_industry'} ../input/gcamdata/xml/other_industry.xml
# ScenarioComponents {'name': 'industry_income_elas'} ../input/gcamdata/xml/other_industry_incelas_gssp2.xml
# ScenarioComponents {'name': 'iron_steel'} ../input/gcamdata/xml/iron_steel.xml
# ScenarioComponents {'name': 'iron_steel_income_elas'} ../input/gcamdata/xml/iron_steel_incelas_gssp2.xml
# ScenarioComponents {'name': 'Off_road'} ../input/gcamdata/xml/Off_road.xml
# ScenarioComponents {'name': 'Off_road_income_elas'} ../input/gcamdata/xml/Off_road_incelas_gssp2.xml
# ScenarioComponents {'name': 'chemical'} ../input/gcamdata/xml/chemical.xml
# ScenarioComponents {'name': 'chemical_income_elas'} ../input/gcamdata/xml/chemical_incelas_gssp2.xml
# ScenarioComponents {'name': 'aluminum'} ../input/gcamdata/xml/aluminum.xml
# ScenarioComponents {'name': 'aluminum_income_elas'} ../input/gcamdata/xml/aluminum_incelas_gssp2.xml
# ScenarioComponents {'name': 'cement'} ../input/gcamdata/xml/cement.xml
# ScenarioComponents {'name': 'cement_income_elas'} ../input/gcamdata/xml/cement_incelas_gssp2.xml
# ScenarioComponents {'name': 'fertilizer_energy'} ../input/gcamdata/xml/en_Fert.xml
# ScenarioComponents {'name': 'hddcdd'} ../input/gcamdata/xml/HDDCDD_constdd_no_GCM.xml
# ScenarioComponents {'name': 'building'} ../input/gcamdata/xml/building_det.xml
# ScenarioComponents {'name': 'transportation'} ../input/gcamdata/xml/transportation_UCD_CORE.xml
# ScenarioComponents {'name': 'carbon_content'} ../input/gcamdata/xml/Ccoef.xml
# ScenarioComponents {'name': 'carbon_storage'} ../input/gcamdata/xml/Cstorage.xml
# ScenarioComponents {'name': 'ag_base'} ../input/gcamdata/xml/ag_For_Past_bio_base_IRR_MGMT.xml
# ScenarioComponents {'name': 'ag_cost'} ../input/gcamdata/xml/ag_cost_IRR_MGMT.xml
# ScenarioComponents {'name': 'ag_prodchange'} ../input/gcamdata/xml/ag_prodchange_ref_IRR_MGMT.xml
# ScenarioComponents {'name': 'residue_bio'} ../input/gcamdata/xml/resbio_input_IRR_MGMT.xml
# ScenarioComponents {'name': 'animal'} ../input/gcamdata/xml/an_input.xml
# ScenarioComponents {'name': 'fertilizer'} ../input/gcamdata/xml/ag_Fert_IRR_MGMT.xml
# ScenarioComponents {'name': 'land1'} ../input/gcamdata/xml/land_input_1.xml
# ScenarioComponents {'name': 'land2'} ../input/gcamdata/xml/land_input_2.xml
# ScenarioComponents {'name': 'land3'} ../input/gcamdata/xml/land_input_3_IRR.xml
# ScenarioComponents {'name': 'land4'} ../input/gcamdata/xml/land_input_4_IRR_MGMT.xml
# ScenarioComponents {'name': 'land5'} ../input/gcamdata/xml/land_input_5_IRR_MGMT.xml
# ScenarioComponents {'name': 'protected_land2'} ../input/gcamdata/xml/protected_land_input_2.xml
# ScenarioComponents {'name': 'protected_land3'} ../input/gcamdata/xml/protected_land_input_3.xml
# ScenarioComponents {'name': 'demand'} ../input/gcamdata/xml/ag_an_demand_input.xml
# ScenarioComponents {'name': 'bio_trade'} ../input/gcamdata/xml/bio_trade.xml
# ScenarioComponents {'name': 'ag_trade'} ../input/gcamdata/xml/ag_trade.xml
# ScenarioComponents {'name': 'unlim_supply_water'} ../input/gcamdata/xml/unlimited_water_supply.xml
# ScenarioComponents {'name': 'water_supply'} ../input/gcamdata/xml/water_supply_constrained.xml
# ScenarioComponents {'name': 'water_desal'} ../input/gcamdata/xml/desalination.xml
# ScenarioComponents {'name': 'water_td'} ../input/gcamdata/xml/water_td.xml
# ScenarioComponents {'name': 'efw_coefs'} ../input/gcamdata/xml/EFW_input_coefs.xml
# ScenarioComponents {'name': 'efw_irr'} ../input/gcamdata/xml/EFW_irrigation.xml
# ScenarioComponents {'name': 'efw_mfg'} ../input/gcamdata/xml/EFW_manufacturing.xml
# ScenarioComponents {'name': 'efw_muni'} ../input/gcamdata/xml/EFW_municipal.xml
# ScenarioComponents {'name': 'ag_water'} ../input/gcamdata/xml/ag_water_input_IRR_MGMT.xml
# ScenarioComponents {'name': 'elec_water_coef'} ../input/gcamdata/xml/electricity_water_coefs.xml
# ScenarioComponents {'name': 'ind_water'} ../input/gcamdata/xml/water_demand_industry.xml
# ScenarioComponents {'name': 'an_water'} ../input/gcamdata/xml/water_demand_livestock.xml
# ScenarioComponents {'name': 'municipal_water'} ../input/gcamdata/xml/water_demand_municipal.xml
# ScenarioComponents {'name': 'primary_ene_water'} ../input/gcamdata/xml/water_demand_primary.xml
# ScenarioComponents {'name': 'ind_urb_proc'} ../input/gcamdata/xml/ind_urb_processing_sectors.xml
# ScenarioComponents {'name': 'nonco2_energy'} ../input/gcamdata/xml/all_energy_emissions.xml
# ScenarioComponents {'name': 'nonco2_fgas'} ../input/gcamdata/xml/all_fgas_emissions.xml
# ScenarioComponents {'name': 'nonco2_unmgd'} ../input/gcamdata/xml/all_unmgd_emissions.xml
# ScenarioComponents {'name': 'nonco2_aglu'} ../input/gcamdata/xml/all_aglu_emissions_IRR_MGMT.xml
# ScenarioComponents {'name': 'nonco2_aglu_prot'} ../input/gcamdata/xml/all_protected_unmgd_emissions.xml
# ScenarioComponents {'name': 'nonco2_em_controls'} ../input/gcamdata/xml/emission_factor_controls.xml
# ScenarioComponents {'name': 'nonco2_energy'} ../input/gcamdata/xml/all_energy_emissions_MAC.xml
# ScenarioComponents {'name': 'nonco2_fgas'} ../input/gcamdata/xml/all_fgas_emissions_MAC.xml
# ScenarioComponents {'name': 'nonco2_aglu'} ../input/gcamdata/xml/all_aglu_emissions_IRR_MGMT_MAC.xml
# ScenarioComponents {'name': 'nonco2_proc'} ../input/gcamdata/xml/ind_urb_processing_sectors_MAC.xml
# ScenarioComponents {'name': 'bio_feedstock_limit'} ../input/gcamdata/xml/liquids_limits.xml
# ScenarioComponents {'name': 'bio_elec_w_feed_limit'} ../input/gcamdata/xml/water_elec_liquids_limits.xml
# ScenarioComponents {'name': 'bio_neg_emiss_budget'} ../input/gcamdata/xml/negative_emissions_budget_gSSP2.xml
# ScenarioComponents {'name': 'bio_externality'} ../input/gcamdata/xml/bio_externality.xml
# ScenarioComponents {'name': 'wind_update'} ../input/gcamdata/xml/onshore_wind.xml
# ScenarioComponents {'name': 'solver'} ../input/solution/cal_broyden_config.xml
# ScenarioComponents {'name': 'water_supply'} C:/Users/birnb/Documents/Tufts Research/GCIMS/birnbaum-etal_2024_HydroVariability/Data/SWM_xml/stochastic_runoff_100.xml
#
# Strings {'name': 'scenarioName'} stochastic_runoff_random_100
# Strings {'name': 'debug-region'} USA
# Strings {'name': 'MAGICC-input-dir'} ../input/magicc/inputs
# Strings {'name': 'MAGICC-output-dir'} ../output
# Strings {'name': 'AbatedGasForCostCurves'} CO2
#
# Bools {'name': 'CalibrationActive'} 1
# Bools {'name': 'BatchMode'} 0
# Bools {'name': 'find-path'} 0
# Bools {'name': 'createCostCurve'} 0
# Bools {'name': 'debugChecking'} 0
# Bools {'name': 'simulActive'} 1
# Bools {'name': 'PrintValuesOnGraphs'} 1
# Bools {'name': 'ShowNullPaths'} 0
# Bools {'name': 'PrintPrices'} 1
# Bools {'name': 'QuitFirstFailure'} 0
#
# Ints {'name': 'numMarketsToFindSD'} 10
# Ints {'name': 'numPointsForSD'} 21
# Ints {'name': 'numPointsForCO2CostCurve'} 5
# Ints {'name': 'carbon-output-start-year'} 1705
# Ints {'name': 'climateOutputInterval'} 5
# Ints {'name': 'parallel-grain-size'} 50
# Ints {'name': 'stop-period'} -1
# Ints {'name': 'stop-year'} -1
# Ints {'name': 'restart-period'} -1
# Ints {'name': 'restart-year'} -1
# Ints {'name': 'max-parallelism'} -1
